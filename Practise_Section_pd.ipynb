# %%
import pandas as pd

# %%
customers= pd.read_csv('messy_customers.csv')

# %%
customers
# Out:
#     customer_id customer_name       city signup_date
# 0         C0001    Customer_1      DELHI  2024-02-09
# 1         C0002    Customer_2      delhi  2025-04-20
# 2         C0003    Customer_3  Bangalore  2024-08-19
# 3         C0004    Customer_4       Pune  2023-08-08
# 4         C0005           NaN  Bengaluru  2024-03-04
# ..          ...           ...        ...         ...
# 515       C0391  Customer_391    Kolkata  2023-01-07
# 516       C0483  Customer_483      Delhi  2023-02-25
# 517       C0473  Customer_473  Bangalore  2023-12-05
# 518       C0417  Customer_417  Bangalore  2025-01-24
# 519       C0303  Customer_303    Kolkata  2024-03-23
#
# [520 rows x 4 columns]

# %%
orders= pd.read_csv('messy_orders.csv')

# %%
orders
# Out:
#      order_id customer_id  order_date    payment_method
# 0      O00001       C0058  09/05/2024  Cash on Delivery
# 1      O00002       C0410  2024-02-01               upi
# 2      O00003       C0429  13/04/2025              Cash
# 3      O00004       C0272  2024-02-25        Debit Card
# 4      O00005       C0411  04-26-2025       credit card
# ...       ...         ...         ...               ...
# 1235   O01078       C0222  03-15-2025  Cash on Delivery
# 1236   O00944       C0014  04-08-2024       credit card
# 1237   O00128       C0383  03-31-2025       Credit Card
# 1238   O00966       C0053  23/02/2024               upi
# 1239   O00313       C0428  12-21-2024  Cash on Delivery
#
# [1240 rows x 4 columns]

# %%
products= pd.read_csv('messy_products.csv')

# %%
products
# Out:
#    product_id    product_name     category  base_price
# 0        P001  Lenovo IdeaPad       Tablet     28151.0
# 1        P002     Samsung Tab   Smartphone     68660.0
# 2        P003     HP Pavilion  Accessories         NaN
# 3        P004      Lenovo Tab       tablet         NaN
# 4        P005         OnePlus       Tablet         NaN
# ..        ...             ...          ...         ...
# 85       P022     Samsung Tab    Accessory         NaN
# 86       P052    Xiaomi Redmi  smart phone         NaN
# 87       P010       iPhone 13  smart phone         NaN
# 88       P059         OnePlus  Accessories         NaN
# 89       P033  Wireless Mouse       laptop     47453.0
#
# [90 rows x 4 columns]

# %%
order_items= pd.read_csv('messy_order_items.csv')

# %%
order_items
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %% [markdown]
# working on MESSY_CUSTOMERS

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    520 non-null    object
#  1   customer_name  492 non-null    object
#  2   city           479 non-null    object
#  3   signup_date    520 non-null    object
# dtypes: object(4)
# memory usage: 16.4+ KB

# %% [markdown]
# Assigning right Datatype(Especially datetime ,here)

# %%
customers['signup_date']=pd.to_datetime(customers['signup_date'])

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    520 non-null    object
#  1   customer_name  492 non-null    object
#  2   city           479 non-null    object
#  3   signup_date    520 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 16.4+ KB

# %%
customers.describe()
# Out:
#                          signup_date
# count                            520
# mean   2024-03-05 20:10:09.230769408
# min              2023-01-01 00:00:00
# 25%              2023-07-25 12:00:00
# 50%              2024-02-13 12:00:00
# 75%              2024-10-20 06:00:00
# max              2025-06-19 00:00:00

# %%
customers.shape
# Out:
# (520, 4)

# %% [markdown]
# Handling DUPLICACY

# %%
customers.duplicated().sum()
# Out:
# np.int64(20)

# %%
customers.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515     True
# 516     True
# 517     True
# 518     True
# 519     True
# Length: 520, dtype: bool

# %%
customers.loc[customers.duplicated()]
# Out:
#     customer_id customer_name       city signup_date
# 500       C0309  Customer_309    Kolkata  2025-05-09
# 501       C0014   Customer_14      delhi  2024-08-18
# 502       C0415  Customer_415    Kolkata  2025-04-05
# 503       C0033   Customer_33     mumbai  2024-04-30
# 504       C0461  Customer_461    Chennai  2024-06-02
# 505       C0156  Customer_156       Pune  2024-08-07
# 506       C0250  Customer_250     Mumbai  2024-12-31
# 507       C0218  Customer_218      delhi  2025-02-02
# 508       C0222  Customer_222  Hyderabad  2024-05-20
# 509       C0294  Customer_294  Hyderabad  2023-09-12
# 510       C0133  Customer_133     Mumbai  2025-05-10
# 511       C0466  Customer_466     mumbai  2023-04-28
# 512       C0439  Customer_439  Hyderabad  2023-07-03
# 513       C0180  Customer_180        NaN  2025-01-16
# 514       C0498  Customer_498     Mumbai  2023-06-13
# 515       C0391  Customer_391    Kolkata  2023-01-07
# 516       C0483  Customer_483      Delhi  2023-02-25
# ...

# %%
customers.drop_duplicates(inplace=True)

# %%
customers.loc[customers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, city, signup_date]
# Index: []

# %% [markdown]
# Handling NULL values

# %%
customers.isnull().sum()
# Out:
# customer_id       0
# customer_name    28
# city             40
# signup_date       0
# dtype: int64

# %%
customers[customers.isnull().any(axis=1)]
# Out:
#     customer_id customer_name       city signup_date
# 4         C0005           NaN  Bengaluru  2024-03-04
# 10        C0011           NaN      DELHI  2023-10-24
# 15        C0016   Customer_16        NaN  2023-03-06
# 27        C0028           NaN    Kolkata  2023-03-21
# 36        C0037   Customer_37        NaN  2024-01-31
# ..          ...           ...        ...         ...
# 470       C0471  Customer_471        NaN  2025-03-27
# 474       C0475  Customer_475        NaN  2023-02-19
# 477       C0478  Customer_478        NaN  2023-01-02
# 483       C0484           NaN  Bangalore  2023-11-08
# 496       C0497           NaN       Pune  2023-01-26
#
# [66 rows x 4 columns]

# %%
customers['customer_name']=customers['customer_name'].replace({'NaN':'rajesh'})#(wrong as NaN is not a   string)

# %%
customers[customers.isnull().any(axis=1)]
# Out:
#     customer_id customer_name       city signup_date
# 4         C0005           NaN  Bengaluru  2024-03-04
# 10        C0011           NaN      DELHI  2023-10-24
# 15        C0016   Customer_16        NaN  2023-03-06
# 27        C0028           NaN    Kolkata  2023-03-21
# 36        C0037   Customer_37        NaN  2024-01-31
# ..          ...           ...        ...         ...
# 470       C0471  Customer_471        NaN  2025-03-27
# 474       C0475  Customer_475        NaN  2023-02-19
# 477       C0478  Customer_478        NaN  2023-01-02
# 483       C0484           NaN  Bangalore  2023-11-08
# 496       C0497           NaN       Pune  2023-01-26
#
# [66 rows x 4 columns]

# %% [markdown]
# Using Function to fill Null Values

# %%
def fill():
    i=0
    while i<497:
        if pd.isna(customers.loc[i,'customer_name']):
            customers.loc[i,'customer_name']=f'customer_{i}'
        i+=1
fill()

# %%
customers[customers.isnull().any(axis=1)]
# Out:
#     customer_id customer_name city signup_date
# 15        C0016   Customer_16  NaN  2023-03-06
# 36        C0037   Customer_37  NaN  2024-01-31
# 71        C0072   Customer_72  NaN  2023-06-15
# 73        C0074   Customer_74  NaN  2024-07-10
# 83        C0084   Customer_84  NaN  2023-01-30
# 85        C0086   Customer_86  NaN  2024-09-11
# 97        C0098   Customer_98  NaN  2024-02-10
# 98        C0099   Customer_99  NaN  2023-03-28
# 105       C0106  Customer_106  NaN  2024-10-27
# 106       C0107  Customer_107  NaN  2023-05-23
# 119       C0120  Customer_120  NaN  2023-05-04
# 128       C0129  Customer_129  NaN  2023-10-11
# 145       C0146  Customer_146  NaN  2024-01-10
# 157       C0158  Customer_158  NaN  2023-07-07
# 179       C0180  Customer_180  NaN  2025-01-16
# 182       C0183  Customer_183  NaN  2025-06-19
# 201       C0202  Customer_202  NaN  2024-05-21
# 202       C0203  Customer_203  NaN  2024-09-25
# 205       C0206  Customer_206  NaN  2025-04-11
# ...

# %%
customers.isnull().sum()
# Out:
# customer_id       0
# customer_name     0
# city             40
# signup_date       0
# dtype: int64

# %%
customers.drop(columns=['city'],inplace=True)
#Ran 2nd time so it shows error as city was already droped

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# signup_date      0
# dtype: int64

# %% [markdown]
# Handling INCONSISTENCY of data

# %%
customers['customer_name']=customers['customer_name'].str.title()

# %%
customers
# Out:
#     customer_id customer_name signup_date
# 0         C0001    Customer_1  2024-02-09
# 1         C0002    Customer_2  2025-04-20
# 2         C0003    Customer_3  2024-08-19
# 3         C0004    Customer_4  2023-08-08
# 4         C0005    Customer_4  2024-03-04
# ..          ...           ...         ...
# 495       C0496  Customer_496  2023-01-01
# 496       C0497  Customer_496  2023-01-26
# 497       C0498  Customer_498  2023-06-13
# 498       C0499  Customer_499  2023-01-13
# 499       C0500  Customer_500  2023-07-21
#
# [500 rows x 3 columns]

# %%
customers.loc[customers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, signup_date]
# Index: []

# %% [markdown]
# Adding NEW COLUMN in dataframe by using function apply

# %%
def namcity(a):
    
    if a==f'{a}':
        return f"city_{a}"

# %%
customers['City']=customers['customer_name'].apply(namcity)

# %%
customers
# Out:
#     customer_id customer_name signup_date               City
# 0         C0001    Customer_1  2024-02-09    city_Customer_1
# 1         C0002    Customer_2  2025-04-20    city_Customer_2
# 2         C0003    Customer_3  2024-08-19    city_Customer_3
# 3         C0004    Customer_4  2023-08-08    city_Customer_4
# 4         C0005    Customer_4  2024-03-04    city_Customer_4
# ..          ...           ...         ...                ...
# 495       C0496  Customer_496  2023-01-01  city_Customer_496
# 496       C0497  Customer_496  2023-01-26  city_Customer_496
# 497       C0498  Customer_498  2023-06-13  city_Customer_498
# 498       C0499  Customer_499  2023-01-13  city_Customer_499
# 499       C0500  Customer_500  2023-07-21  city_Customer_500
#
# [500 rows x 4 columns]

# %% [markdown]
# working on MESSY_ORDERS

# %%
orders
# Out:
#      order_id customer_id  order_date    payment_method
# 0      O00001       C0058  09/05/2024  Cash on Delivery
# 1      O00002       C0410  2024-02-01               upi
# 2      O00003       C0429  13/04/2025              Cash
# 3      O00004       C0272  2024-02-25        Debit Card
# 4      O00005       C0411  04-26-2025       credit card
# ...       ...         ...         ...               ...
# 1235   O01078       C0222  03-15-2025  Cash on Delivery
# 1236   O00944       C0014  04-08-2024       credit card
# 1237   O00128       C0383  03-31-2025       Credit Card
# 1238   O00966       C0053  23/02/2024               upi
# 1239   O00313       C0428  12-21-2024  Cash on Delivery
#
# [1240 rows x 4 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1240 non-null   object
#  1   customer_id     1240 non-null   object
#  2   order_date      1240 non-null   object
#  3   payment_method  1095 non-null   object
# dtypes: object(4)
# memory usage: 38.9+ KB

# %% [markdown]
# assigning right DATETIME datatype with mixed format

# %%
orders['order_date']=pd.to_datetime(orders['order_date'],format='mixed')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1240 non-null   object
#  1   customer_id     1240 non-null   object
#  2   order_date      1240 non-null   datetime64[ns]
#  3   payment_method  1095 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 38.9+ KB

# %%
orders.describe()
# Out:
#                           order_date
# count                           1240
# mean   2024-09-03 03:41:48.387096832
# min              2024-01-01 00:00:00
# 25%              2024-04-24 00:00:00
# 50%              2024-08-24 00:00:00
# 75%              2025-01-05 12:00:00
# max              2025-12-03 00:00:00

# %%
orders['payment_method']=orders['payment_method'].astype('str')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1240 non-null   object
#  1   customer_id     1240 non-null   object
#  2   order_date      1240 non-null   datetime64[ns]
#  3   payment_method  1240 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 38.9+ KB

# %% [markdown]
# DUPLICACY

# %%
orders.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1235     True
# 1236     True
# 1237     True
# 1238     True
# 1239     True
# Length: 1240, dtype: bool

# %%
orders.loc[orders.duplicated()]
# Out:
#      order_id customer_id order_date    payment_method
# 1200   O00403       C0148 2024-10-28        Debit Card
# 1201   O00375       C0427 2024-07-03       credit card
# 1202   O00279       C0286 2024-12-06              Cash
# 1203   O00015       C0329 2024-02-09  Cash on Delivery
# 1204   O00147       C0303 2024-06-23       Credit Card
# 1205   O00186       C0333 2024-09-21              Cash
# 1206   O01084       C0186 2024-04-11              Cash
# 1207   O01188       C0094 2024-02-05               UPI
# 1208   O00350       C0328 2024-04-27       Credit Card
# 1209   O00526       C0068 2025-04-19              Cash
# 1210   O01122       C0084 2025-03-11       credit card
# 1211   O01152       C0104 2024-04-08               UPI
# 1212   O00681       C0313 2024-12-04  Cash on Delivery
# 1213   O00390       C0437 2025-04-10       credit card
# 1214   O01103       C0345 2024-03-22               nan
# 1215   O00195       C0125 2024-09-23  Cash on Delivery
# ...

# %%
orders.duplicated().sum()
# Out:
# np.int64(40)

# %%
orders.drop_duplicates(inplace=True)

# %% [markdown]
# NULL values

# %%
orders[orders.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, payment_method]
# Index: []

# %%
orders[orders['payment_method'].isna()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, payment_method]
# Index: []

# %%
orders['payment_method']=orders['payment_method'].replace({'nan':'Unknown'})

# %%
orders
# Out:
#      order_id customer_id order_date    payment_method
# 0      O00001       C0058 2024-09-05  Cash on Delivery
# 1      O00002       C0410 2024-02-01               upi
# 2      O00003       C0429 2025-04-13              Cash
# 3      O00004       C0272 2024-02-25        Debit Card
# 4      O00005       C0411 2025-04-26       credit card
# ...       ...         ...        ...               ...
# 1195   O01196       C0392 2024-09-14           Unknown
# 1196   O01197       C0260 2024-04-09           Unknown
# 1197   O01198       C0459 2024-05-29           Unknown
# 1198   O01199       C0130 2024-03-13           Unknown
# 1199   O01200       C0448 2024-03-06               UPI
#
# [1200 rows x 4 columns]

# %% [markdown]
# INCONSISTENCY

# %%
orders['payment_method']=orders['payment_method'].str.title()

# %%
orders['payment_method']
# Out:
# 0       Cash On Delivery
# 1                    Upi
# 2                   Cash
# 3             Debit Card
# 4            Credit Card
#               ...
# 1195             Unknown
# 1196             Unknown
# 1197             Unknown
# 1198             Unknown
# 1199                 Upi
# Name: payment_method, Length: 1200, dtype: object

# %% [markdown]
# Merging DataFrames

# %%
combined1=pd.merge(customers,orders,on='customer_id') # by default it applies inner join

# %%
combined1
# Out:
#      customer_id customer_name signup_date               City order_id  \
# 0          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 1          C0001    Customer_1  2024-02-09    city_Customer_1   O00541
# 2          C0001    Customer_1  2024-02-09    city_Customer_1   O00675
# 3          C0001    Customer_1  2024-02-09    city_Customer_1   O00782
# 4          C0001    Customer_1  2024-02-09    city_Customer_1   O00987
# ...          ...           ...         ...                ...      ...
# 1195       C0497  Customer_496  2023-01-26  city_Customer_496   O00608
# 1196       C0498  Customer_498  2023-06-13  city_Customer_498   O00448
# 1197       C0498  Customer_498  2023-06-13  city_Customer_498   O00489
# 1198       C0498  Customer_498  2023-06-13  city_Customer_498   O00789
# 1199       C0498  Customer_498  2023-06-13  city_Customer_498   O01049
#
#      order_date payment_method
# 0    2024-02-27     Debit Card
# 1    2024-10-19            Upi
# ...

# %% [markdown]
# Exporting as csv and excel

# %%
combined1.to_csv('joined_data_messy.csv',index=False)

# %%
combined1.to_excel('result_messy.xlsx',sheet_name='merge_data_messy')

# %%
y = combined1.groupby("payment_method")['order_id'].count()

# %%
y
# Out:
# payment_method
# Cash                163
# Cash On Delivery    140
# Credit Card         309
# Debit Card          134
# Unknown             141
# Upi                 313
# Name: order_id, dtype: int64

# %%
combined1['payment_method']=combined1['payment_method'].replace({'Cash':'Cash On Delivery'})

# %%
y = combined1.groupby("payment_method")['order_id'].count()

# %%
y
# Out:
# payment_method
# Cash On Delivery    303
# Credit Card         309
# Debit Card          134
# Unknown             141
# Upi                 313
# Name: order_id, dtype: int64

# %%
x=combined1.pivot_table("City",'payment_method','order_id','count')

# %%
x
# Out:
# order_id          O00001  O00002  O00003  O00004  O00005  O00006  O00007  \
# payment_method
# Cash On Delivery     1.0     NaN     1.0     NaN     NaN     NaN     NaN
# Credit Card          NaN     NaN     NaN     NaN     1.0     1.0     1.0
# Debit Card           NaN     NaN     NaN     1.0     NaN     NaN     NaN
# Unknown              NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Upi                  NaN     1.0     NaN     NaN     NaN     NaN     NaN
#
# order_id          O00008  O00009  O00010  ...  O01191  O01192  O01193  O01194  \
# payment_method                            ...
# Cash On Delivery     NaN     1.0     NaN  ...     NaN     1.0     NaN     NaN
# Credit Card          1.0     NaN     1.0  ...     NaN     NaN     NaN     NaN
# Debit Card           NaN     NaN     NaN  ...     1.0     NaN     NaN     NaN
# Unknown              NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# ...

# %%
order_items
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  2050 non-null   int64
#  1   order_id       2050 non-null   object
#  2   product_id     2050 non-null   object
#  3   quantity       1732 non-null   float64
#  4   unit_price     1039 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 80.2+ KB

# %%
order_items.loc[order_items.duplicated()]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 2000            689   O01021       P004       0.0         NaN
# 2001            436   O00386       P012       3.0     31320.0
# 2002           1596   O00176       P065       1.0         NaN
# 2003           1775   O00896       P030       3.0     40678.0
# 2004           1904   O00312       P031       3.0         NaN
# 2005           1420   O00327       P039       2.0     53326.0
# 2006            411   O01054       P072       0.0     85189.0
# 2007            697   O00355       P063       4.0     55126.0
# 2008           1006   O00750       P041       0.0         NaN
# 2009            861   O00205       P060       4.0     55826.0
# 2010           1532   O00015       P075       2.0     56095.0
# 2011            111   O01090       P018       0.0     41057.0
# 2012           1261   O00085       P046       0.0     76395.0
# 2013            746   O00155       P031       1.0         NaN
# ...

# %%
order_items.duplicated().sum()
# Out:
# np.int64(50)

# %%
order_items.drop_duplicates(inplace=True)

# %%
order_items.isna().sum()
# Out:
# order_item_id      0
# order_id           0
# product_id         0
# quantity         313
# unit_price       990
# dtype: int64

# %%
order_items[order_items.isna().any(axis=1)]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 5                 6   O00137       P023       1.0         NaN
# 6                 7   O00288       P070       0.0         NaN
# 8                 9   O00409       P015       1.0         NaN
# ...             ...      ...        ...       ...         ...
# 1991           1992   O00734       P026       2.0         NaN
# 1993           1994   O00899       P054       NaN     51205.0
# 1994           1995   O00364       P005       3.0         NaN
# 1996           1997   O00629       P017       4.0         NaN
# 1999           2000   O00596       P010       NaN     33991.0
#
# [1155 rows x 5 columns]

# %%
order_items.isna().mean()*100
# Out:
# order_item_id     0.00
# order_id          0.00
# product_id        0.00
# quantity         15.65
# unit_price       49.50
# dtype: float64

# %%
order_items.groupby('product_id')['unit_price'].agg(['count','min','max','median'])
# Out:
#             count      min      max   median
# product_id
# P001            8   5740.0  53114.0  32938.0
# P002           15   1509.0  88990.0  59279.0
# P003           11  10513.0  64992.0  40345.0
# P004           13   3445.0  88764.0  26159.0
# P005           10   8018.0  84879.0  37524.5
# ...           ...      ...      ...      ...
# P076           29   6891.0  89156.0  58608.0
# P077           12   3653.0  86726.0  36191.5
# P078           11   6791.0  86702.0  46377.0
# P079           14   3742.0  84451.0  53168.5
# P080            9  24250.0  80491.0  56159.0
#
# [80 rows x 4 columns]

# %%
price_map=order_items.groupby('product_id')['unit_price'].median()
order_items['unit_price']=order_items['unit_price'].fillna(order_items['product_id'].map(price_map))

# %%
order_items
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0     42539.0
# 1                 2   O00857       P010       1.0     38223.0
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 1995           1996   O00944       P007       4.0     64106.0
# 1996           1997   O00629       P017       4.0     54245.5
# 1997           1998   O00703       P008       0.0     76524.0
# 1998           1999   O01083       P043       3.0     18251.0
# 1999           2000   O00596       P010       NaN     33991.0
#
# [2000 rows x 5 columns]

# %%
order_items['quantity'].describe()
# Out:
# count    1687.000000
# mean        1.998814
# std         1.409171
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         4.000000
# Name: quantity, dtype: float64

# %%
order_items['quantity']=order_items['quantity'].fillna(order_items['quantity'].median())

# %%
order_items['quantity']
# Out:
# 0       2.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1995    4.0
# 1996    4.0
# 1997    0.0
# 1998    3.0
# 1999    2.0
# Name: quantity, Length: 2000, dtype: float64

# %%
order_items
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0     42539.0
# 1                 2   O00857       P010       1.0     38223.0
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 1995           1996   O00944       P007       4.0     64106.0
# 1996           1997   O00629       P017       4.0     54245.5
# 1997           1998   O00703       P008       0.0     76524.0
# 1998           1999   O01083       P043       3.0     18251.0
# 1999           2000   O00596       P010       2.0     33991.0
#
# [2000 rows x 5 columns]

# %%
products
# Out:
#    product_id    product_name     category  base_price
# 0        P001  Lenovo IdeaPad       Tablet     28151.0
# 1        P002     Samsung Tab   Smartphone     68660.0
# 2        P003     HP Pavilion  Accessories         NaN
# 3        P004      Lenovo Tab       tablet         NaN
# 4        P005         OnePlus       Tablet         NaN
# ..        ...             ...          ...         ...
# 85       P022     Samsung Tab    Accessory         NaN
# 86       P052    Xiaomi Redmi  smart phone         NaN
# 87       P010       iPhone 13  smart phone         NaN
# 88       P059         OnePlus  Accessories         NaN
# 89       P033  Wireless Mouse       laptop     47453.0
#
# [90 rows x 4 columns]

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    90 non-null     object
#  1   product_name  90 non-null     object
#  2   category      90 non-null     object
#  3   base_price    33 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 2.9+ KB

# %%
products.loc[products.duplicated()]
# Out:
#    product_id    product_name     category  base_price
# 80       P076  Wireless Mouse    Accessory     15249.0
# 81       P062   Dell Inspiron       Tablet         NaN
# 82       P072   Dell Inspiron       Tablet         NaN
# 83       P017        Keyboard   Smartphone         NaN
# 84       P020   Dell Inspiron   Smartphone         NaN
# 85       P022     Samsung Tab    Accessory         NaN
# 86       P052    Xiaomi Redmi  smart phone         NaN
# 87       P010       iPhone 13  smart phone         NaN
# 88       P059         OnePlus  Accessories         NaN
# 89       P033  Wireless Mouse       laptop     47453.0

# %%
products.duplicated().sum()
# Out:
# np.int64(10)

# %%
products.drop_duplicates(inplace=True)

# %%
products.isna().sum()
# Out:
# product_id       0
# product_name     0
# category         0
# base_price      49
# dtype: int64

# %%
products.groupby('product_id')['base_price'].agg(['count','min','max','mean'])
# Out:
#             count      min      max     mean
# product_id
# P001            1  28151.0  28151.0  28151.0
# P002            1  68660.0  68660.0  68660.0
# P003            0      NaN      NaN      NaN
# P004            0      NaN      NaN      NaN
# P005            0      NaN      NaN      NaN
# ...           ...      ...      ...      ...
# P076            1  15249.0  15249.0  15249.0
# P077            0      NaN      NaN      NaN
# P078            1  70378.0  70378.0  70378.0
# P079            0      NaN      NaN      NaN
# P080            1  82478.0  82478.0  82478.0
#
# [80 rows x 4 columns]

# %%
bprice_map=order_items.groupby('product_id')['unit_price'].mean()
products['base_price']=products['base_price'].fillna(products['product_id'].map(bprice_map))

# %%
products[products.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, base_price]
# Index: []

# %%
products['product_name']=products['product_name'].str.title()

# %%
products
# Out:
#    product_id    product_name     category    base_price
# 0        P001  Lenovo Ideapad       Tablet  28151.000000
# 1        P002     Samsung Tab   Smartphone  68660.000000
# 2        P003     Hp Pavilion  Accessories  40489.000000
# 3        P004      Lenovo Tab       tablet  32011.400000
# 4        P005         Oneplus       Tablet  41247.388889
# ..        ...             ...          ...           ...
# 75       P076  Wireless Mouse    Accessory  15249.000000
# 76       P077  Wireless Mouse  smart phone  39614.833333
# 77       P078         Usb Hub    Accessory  70378.000000
# 78       P079         Oneplus       tablet  49850.653846
# 79       P080         Oneplus       laptop  82478.000000
#
# [80 rows x 4 columns]

# %%
products['category']=products['category'].str.title()

# %%
products
# Out:
#    product_id    product_name     category    base_price
# 0        P001  Lenovo Ideapad       Tablet  28151.000000
# 1        P002     Samsung Tab   Smartphone  68660.000000
# 2        P003     Hp Pavilion  Accessories  40489.000000
# 3        P004      Lenovo Tab       Tablet  32011.400000
# 4        P005         Oneplus       Tablet  41247.388889
# ..        ...             ...          ...           ...
# 75       P076  Wireless Mouse    Accessory  15249.000000
# 76       P077  Wireless Mouse  Smart Phone  39614.833333
# 77       P078         Usb Hub    Accessory  70378.000000
# 78       P079         Oneplus       Tablet  49850.653846
# 79       P080         Oneplus       Laptop  82478.000000
#
# [80 rows x 4 columns]

# %%
combined2=pd.merge(order_items,products,on='product_id')

# %%
combined2
# Out:
#       order_item_id order_id product_id  quantity  unit_price    product_name  \
# 0                 1   O00380       P033       2.0     42539.0  Wireless Mouse
# 1                 2   O00857       P010       1.0     38223.0       Iphone 13
# 2                 3   O00589       P007       2.0     77415.0     Hp Pavilion
# 3                 4   O00112       P045       2.0     49066.0      Lenovo Tab
# 4                 5   O00322       P036       2.0     58380.0  Lenovo Ideapad
# ...             ...      ...        ...       ...         ...             ...
# 1995           1996   O00944       P007       4.0     64106.0     Hp Pavilion
# 1996           1997   O00629       P017       4.0     54245.5        Keyboard
# 1997           1998   O00703       P008       0.0     76524.0     Hp Pavilion
# 1998           1999   O01083       P043       3.0     18251.0         Usb Hub
# 1999           2000   O00596       P010       2.0     33991.0       Iphone 13
#
#          category    base_price
# ...

# %%
combined1
# Out:
#      customer_id customer_name signup_date               City order_id  \
# 0          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 1          C0001    Customer_1  2024-02-09    city_Customer_1   O00541
# 2          C0001    Customer_1  2024-02-09    city_Customer_1   O00675
# 3          C0001    Customer_1  2024-02-09    city_Customer_1   O00782
# 4          C0001    Customer_1  2024-02-09    city_Customer_1   O00987
# ...          ...           ...         ...                ...      ...
# 1195       C0497  Customer_496  2023-01-26  city_Customer_496   O00608
# 1196       C0498  Customer_498  2023-06-13  city_Customer_498   O00448
# 1197       C0498  Customer_498  2023-06-13  city_Customer_498   O00489
# 1198       C0498  Customer_498  2023-06-13  city_Customer_498   O00789
# 1199       C0498  Customer_498  2023-06-13  city_Customer_498   O01049
#
#      order_date    payment_method
# 0    2024-02-27        Debit Card
# 1    2024-10-19               Upi
# ...

# %%
final_result=pd.merge(combined1,combined2,on='order_id')

# %%
final_result
# Out:
#      customer_id customer_name signup_date               City order_id  \
# 0          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 1          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 2          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 3          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# 4          C0001    Customer_1  2024-02-09    city_Customer_1   O00309
# ...          ...           ...         ...                ...      ...
# 1995       C0498  Customer_498  2023-06-13  city_Customer_498   O00489
# 1996       C0498  Customer_498  2023-06-13  city_Customer_498   O00789
# 1997       C0498  Customer_498  2023-06-13  city_Customer_498   O01049
# 1998       C0498  Customer_498  2023-06-13  city_Customer_498   O01049
# 1999       C0498  Customer_498  2023-06-13  city_Customer_498   O01049
#
#      order_date payment_method  order_item_id product_id  quantity  \
# ...

# %%
final_result.to_csv('final_data_messy.csv',index=False)

# %%
final_result.to_excel('final_messy.xlsx',sheet_name="merged_data_messy")
